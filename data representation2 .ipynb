# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.axis import Axis  
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
x1 = ['F08','I04','I07','I08','I09']
y1 = [4,2,4,12,2]
x2 = ['I02','I01','I03','I04','I05','I06','I07','I08','J01','J02','J03','J04','J05','J06','J07','J08','J10','K02','K03','K04','K05','K06']
y2 = [19,18,17,16,19,27,13,7,14,22,24,32,19,27,5,3,1,9,15,34,23,12]
x3 = ['I03','I04','J02','J03','J04','J07','K03','K04','K05']
y3 = [5,1,9,6,6,2,12,18,2]
x4 = ['K04','K05']
y4 = [1,2]
x5 = ['I03','I04','I05','I06','I07','I08','I09','I10','J04','J05','J06','J07','J08','J10','K05','K06']
y5 = [5,2,5,24,24,18,6,2,2,7,17,27,6,2,2,17]
x6 = ['I04','I08','I09','I10','J01','J07','K01','K03','K04','K05','K06']
y6 = [2,4,2,2,4,2,6,2,4,5,11]
x7 = ['I07']
y7 = [1]
x8 = ['I05','I06','I07','I08','I09','I10','J05','J06','J07','J08','J10']
y8 = [1,8,11,18,8,14,2,7,3,5,6]
x9 = ['D13','D14','D15','E15','I15','J15']
y9 = [6,4,14,4,2,1]
x10 = ['G15','I10','I15','J10','J15']
y10 = [4,6,5,1,8]
x11 = ['J15']
y11 = [2]

# %%
fig, ax = plt.subplots(figsize=(17,6))
ax.bar(x1, y1, color ='bisque',label = 'beacon 1')
ax.bar(x2, y2, color ='darkolivegreen',label = 'beacon 2')
ax.bar(x3, y3, color ='black',label = 'beacon 3')
ax.bar(x4, y4, color ='tab:blue',label = 'beacon 4')
ax.bar(x5, y5, color ='tab:orange',label = 'beacon 5')
ax.bar(x6, y6, color ='tab:green',label = 'beacon 6')
ax.bar(x7, y7, color ='tab:red',label = 'beacon 7')
ax.bar(x8, y8, color ='tab:purple',label = 'beacon 8')
ax.bar(x9, y9, color ='tab:brown',label = 'beacon 9')
ax.bar(x10, y10, color ='tab:pink',label = 'beacon 10')
ax.bar(x11, y11, color ='tab:gray',label = 'beacon 11')
ax.legend(['beacon 1','beacon 2','beacon 3','beacon 4','beacon 5','beacon 6','beacon 7','beacon 8','beacon 9','beacon 10','beacon 11'], fontsize=10.0)
ax.grid()
#plt.title("Strong RSSI of the beacons", fontweight='bold', fontsize=15.0) 
plt.xlabel("Location", fontweight='bold', fontsize=10.0)
plt.ylabel("Frequency of RSSI values > -85", fontweight='bold', fontsize=10.0)
fig.savefig("D:\\BLE_RSSI_dataset\\RSSIreadings1.png")
#plt.clf()
##########################################################
formatter = ticker.FormatStrFormatter('%1.0f')
Axis.set_major_formatter(ax.yaxis, formatter)
  
for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontsize(15)

# %%
x1 = ['L09']
y1 = [1]
x2 = ['L01','L02','L03','L04','L05','L06','M04','M05','M06','N01','N04','O04','P02']
y2 = [2,2,12,15,8,2,13,2,2,2,10,18,1]
x3 = ['L01','L03','L04','L05','L06','M01','M02','M03','M04','N01','N02','N03','N04','O02','O03','O04','P01','P02','P03']
y3 = [6,10,8,2,1,10,8,12,11,8,10,14,8,1,11,24,5,3,8]
x4 = ['L02','L03','L05','L06','M05','N03','N05','O03','O05','O06','P03']
y4 = [2,1,2,2,2,2,2,5,24,1,10]
x5 = ['K07','K08','L03','L05','L06','L09','M03','M04','M06','N03','N05','N06','O02']
y5 = [10,10,3,3,20,1,2,4,14,4,2,2,3]
x6 = ['K07','K08','L01','L02','L03','L04','L05','L06','M01','M02','M03','M05','M06','N01','N02','N03','N04','N05','N06','O01','O02','O03','O04','O05','O06','P01']
y6 = [9,7,2,9,1,3,6,8,2,10,12,6,14,8,12,14,2,10,12,2,6,8,10,10,15,10]
x8 = ['K07','K08','L09']
y8 = [2,1,2]
x10 = ['L15','N15']
y10 = [2,3]
x11 = ['L15','N15']
y11 = [8,12]
x12 = ['L15','N15']
y12 = [8,2]
x13 = ['L15']
y13 = [2]

# %%
fig, ax = plt.subplots(figsize=(17,6))
ax.bar(x1, y1, color ='bisque',label = 'beacon 1')
ax.bar(x2, y2, color ='darkolivegreen',label = 'beacon 2')
ax.bar(x3, y3, color ='black',label = 'beacon 3')
ax.bar(x4, y4, color ='tab:blue',label = 'beacon 4')
ax.bar(x5, y5, color ='tab:orange',label = 'beacon 5')
ax.bar(x6, y6, color ='tab:green',label = 'beacon 6')
ax.bar(x8, y8, color ='tab:purple',label = 'beacon 8')
ax.bar(x10, y10, color ='tab:pink',label = 'beacon 10')
ax.bar(x11, y11, color ='tab:gray',label = 'beacon 11')
ax.bar(x12, y12, color ='tab:olive',label = 'beacon 12')
ax.bar(x13, y13, color ='tab:cyan',label = 'beacon 13')
ax.legend(['beacon 1','beacon 2','beacon 3','beacon 4','beacon 5','beacon 6','beacon 8','beacon 10','beacon 11','beacon 12','beacon 13'], fontsize=10.0)
ax.grid()
#plt.title("Strong RSSI of the beacons", fontweight='bold', fontsize=15.0) 
plt.xlabel("Location", fontweight='bold', fontsize=10.0)
plt.ylabel("Frequency of RSSI values > -85", fontweight='bold', fontsize=10.0)
fig.savefig("D:\\BLE_RSSI_dataset\\RSSIreadings2.png")
#plt.clf()
##########################################################
formatter = ticker.FormatStrFormatter('%1.0f')
Axis.set_major_formatter(ax.yaxis, formatter)
  
for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontsize(15)

# %%
x2 = ['P04','Q04','Q05']
y2 = [7,7,2]
x3 = ['P04','Q03','Q04','R04','Q01','S03','S04','Q02']
y3 = [13,4,16,6,4,2,5,1]
x4 = ['P05','P06','Q03','Q04','Q05','R01','R02','R03','R04','R05','R06','S01','S02','Q01','S03','S04','S05','S06','T01','T03','T04','U01','U02','U03','U04','U05','Q02','T05','S07','S08','L08','I02']
y4 = [10,4,18,8,22,14,18,15,10,14,2,23,21,6,17,18,20,14,4,6,12,8,8,14,10,8,3,8,4,3,1,2]
x5 = ['L08']
y5 = [1]
x6 = ['P04','P05','P06','Q05','Q06','S07','L08','I02']
y6 = [3,8,8,2,4,2,1,2]
x7 = ['Q04','R03','R05','R06','S03','S05','S06','T05','S07','S08']
y7 = [5,2,6,6,1,2,12,2,9,3]
x8 = ['R15','L08']
y8 = [2,1]
x11 = ['U15']
y11 = [1]
x12 = ['P15','R15','T15']
y12 = [7,12,2]
x13 = ['R15','S15','T15','U15','V15','W15']
y13 = [2,3,5,5,8,17]

# %%
fig, ax = plt.subplots(figsize=(17,6))
ax.bar(x2, y2, color ='darkolivegreen',label = 'beacon 2')
ax.bar(x3, y3, color ='black',label = 'beacon 3')
ax.bar(x4, y4, color ='tab:blue',label = 'beacon 4')
ax.bar(x5, y5, color ='tab:orange',label = 'beacon 5')
ax.bar(x6, y6, color ='tab:green',label = 'beacon 6')
ax.bar(x7, y7, color ='tab:red',label = 'beacon 7')
ax.bar(x8, y8, color ='tab:purple',label = 'beacon 8')
ax.bar(x11, y11, color ='tab:gray',label = 'beacon 11')
ax.bar(x12, y12, color ='tab:olive',label = 'beacon 12')
ax.bar(x13, y13, color ='tab:cyan',label = 'beacon 13')
ax.legend(['beacon 2','beacon 3','beacon 4','beacon 5','beacon 6','beacon 7','beacon 8','beacon 11','beacon 12','beacon 13'], fontsize=10.0)
ax.grid()
#plt.title("Strong RSSI of the beacons", fontweight='bold', fontsize=10.0) 
plt.xlabel("Location", fontweight='bold', fontsize=10.0)
plt.ylabel("Frequency of RSSI values > -85", fontweight='bold', fontsize=10.0)
fig.savefig("D:\\BLE_RSSI_dataset\\RSSIreadings3.png")
#plt.clf()
##########################################################
formatter = ticker.FormatStrFormatter('%1.0f')
Axis.set_major_formatter(ax.yaxis, formatter)
  
for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontsize(15)
